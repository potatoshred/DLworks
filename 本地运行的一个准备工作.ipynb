# %% [markdown]
# # 本地运行的一个准备工作

# %% [markdown]
# #### 1
# 下载
# ![.png](attachment:QQ_1721630710908.png)
#
# #### 2
# 理解第一个段代码这几句话的意思。

# %%
import sys
if 'google.colab' in sys.modules:  # 判断是否在Colab环境中
    print('Running in Colab.') 
    # !pip3 install transformers==4.15.0 timm==0.4.12 fairscale==0.4.4 # 下载所需的包
    # !git clone https://github.com/salesforce/BLIP # 克隆BLIP代码
    # %cd BLIP # 进入BLIP目录

# %% [markdown]
# 👆这几句话是为了在colab在线环境下运行，而我们要在本地运行，就要手动跑一下，改成如下代码：
# （即把if条件判断删掉）

# %% [markdown]
# !pip3 install transformers==4.15.0 timm==0.4.12 fairscale==0.4.4 # 下载所需的包
# !git clone https://github.com/salesforce/BLIP # 克隆BLIP代码
# %cd BLIP # 进入BLIP目录
